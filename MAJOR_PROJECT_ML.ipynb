# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt

# %%
data_train = pd.read_excel("Data_Train.xlsx")
data_test = pd.read_excel("Data_Test.xlsx")
data_train.head(100)
# Out:
#                                                 Name    Location  Year  \
# 0                             Maruti Wagon R LXI CNG      Mumbai  2010
# 1                   Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                       Honda Jazz V     Chennai  2011
# 3                                  Maruti Ertiga VDI     Chennai  2012
# 4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5                    Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6                             Nissan Micra Diesel XV      Jaipur  2013
# 7                  Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8                Volkswagen Vento Diesel Comfortline        Pune  2013
# 9                     Tata Indica Vista Quadrajet LS     Chennai  2012
# 10                                  Maruti Ciaz Zeta       Kochi  2018
# 11                       Honda City 1.5 V AT Sunroof     Kolkata  2012
# 12                             Maruti Swift VDI BSIV      Jaipur  2015
# 13                  Land Rover Range Rover 2.2L Pure       Delhi  2014
# 14                    Land Rover Freelander 2 TD4 SE        Pune  2012
# 15                       Mitsubishi Pajero Sport 4X4       Delhi  2014
# 16                             Honda Amaze S i-Dtech       Kochi  2016
# 17                             Maruti Swift DDiS VDI      Jaipur  2017
# 18               Renault Duster 85PS Diesel RxL Plus       Kochi  2014
# 19  Mercedes-Benz New C-Class C 220 CDI BE Avantgare   Bangalore  2014
# 20                                 BMW 3 Series 320d       Kochi  2014
# 21                     Maruti S Cross DDiS 200 Alpha   Bangalore  2015
# 22              Audi A6 2011-2015 35 TFSI Technology      Mumbai  2015
# 23                             Hyundai i20 1.2 Magna     Kolkata  2010
# 24               Volkswagen Vento Petrol Highline AT     Kolkata  2010
# 25                      Honda City Corporate Edition      Mumbai  2012
# 26                            Nissan Micra Diesel XV   Hyderabad  2012
# 27                     Maruti Alto K10 2010-2014 VXI   Hyderabad  2013
# 28                               Honda WRV i-VTEC VX       Kochi  2018
# 29               Toyota Innova 2.5 V Diesel 7-seater      Mumbai  2007
# ..                                               ...         ...   ...
# 70                   Porsche Cayenne 2009-2014 Turbo      Mumbai  2008
# 71                            Mahindra XUV500 W8 4WD      Mumbai  2015
# 72                         Hyundai i10 Sportz 1.2 AT       Kochi  2012
# 73                           Nissan Terrano XV D Pre       Kochi  2015
# 74                                  Honda Brio VX AT  Coimbatore  2016
# 75                    Audi A6 2.0 TDI Design Edition       Delhi  2014
# 76                          Ford Fiesta 1.4 SXi TDCi      Jaipur  2008
# 77                              Toyota Innova 2.0 G1     Chennai  2006
# 78                   Toyota Innova 2.5 VX 7 STR BSIV   Hyderabad  2012
# 79                            Hyundai Santro Xing XL   Hyderabad  2005
# 80                                  Maruti Swift VDI      Jaipur  2012
# 81                        Tata Zest Revotron 1.2T XE        Pune  2017
# 82                             Honda Amaze SX i-VTEC       Kochi  2016
# 83                              Ford Figo Diesel ZXI   Hyderabad  2012
# 84                                   Maruti Ritz VDi      Jaipur  2013
# 85                               Honda City i VTEC E       Delhi  2009
# 86                       BMW 5 Series 2003-2012 525d       Delhi  2011
# 87                            Hyundai i10 Sportz 1.2        Pune  2009
# 88                          Hyundai Grand i10 Sportz   Bangalore  2016
# 89                            Hyundai Santro Xing XO   Hyderabad  2007
# 90                             Honda Amaze SX i-VTEC      Mumbai  2016
# 91                        Toyota Fortuner 4x2 Manual       Delhi  2014
# 92                  Audi A6 2011-2015 35 TDI Premium  Coimbatore  2018
# 93        Ford Ecosport 1.5 DV5 MT Titanium Optional       Delhi  2013
# 94                            Mahindra XUV500 W8 2WD       Delhi  2014
# 95                             Honda Amaze SX i-DTEC     Kolkata  2015
# 96              Volkswagen Polo Diesel Highline 1.2L     Kolkata  2013
# 97               Hyundai Verna Transform SX VGT CRDi   Ahmedabad  2010
# 98                          Maruti Wagon R VXI BS IV   Bangalore  2016
# 99              Volkswagen Polo Petrol Highline 1.6L       Delhi  2010
#
#     Kilometers_Driven Fuel_Type Transmission      Owner_Type     Mileage  \
# 0               72000       CNG       Manual           First  26.6 km/kg
# 1               41000    Diesel       Manual           First  19.67 kmpl
# 2               46000    Petrol       Manual           First   18.2 kmpl
# 3               87000    Diesel       Manual           First  20.77 kmpl
# 4               40670    Diesel    Automatic          Second   15.2 kmpl
# 5               75000       LPG       Manual           First  21.1 km/kg
# 6               86999    Diesel       Manual           First  23.08 kmpl
# 7               36000    Diesel    Automatic           First  11.36 kmpl
# 8               64430    Diesel       Manual           First  20.54 kmpl
# 9               65932    Diesel       Manual          Second   22.3 kmpl
# 10              25692    Petrol       Manual           First  21.56 kmpl
# 11              60000    Petrol    Automatic           First   16.8 kmpl
# 12              64424    Diesel       Manual           First   25.2 kmpl
# 13              72000    Diesel    Automatic           First   12.7 kmpl
# 14              85000    Diesel    Automatic          Second    0.0 kmpl
# 15             110000    Diesel       Manual           First   13.5 kmpl
# 16              58950    Diesel       Manual           First   25.8 kmpl
# 17              25000    Diesel       Manual           First   28.4 kmpl
# 18              77469    Diesel       Manual           First  20.45 kmpl
# 19              78500    Diesel    Automatic           First  14.84 kmpl
# 20              32982    Diesel    Automatic           First  22.69 kmpl
# 21              55392    Diesel       Manual          Second  23.65 kmpl
# 22              55985    Petrol    Automatic           First  13.53 kmpl
# 23              45807    Petrol       Manual           First   18.5 kmpl
# 24              33000    Petrol    Automatic           First   14.4 kmpl
# 25              51920    Petrol       Manual           First   16.8 kmpl
# 26              54000    Diesel       Manual           First  23.08 kmpl
# 27              54000    Petrol       Manual          Second  20.92 kmpl
# 28              37430    Petrol       Manual           First   17.5 kmpl
# 29             262000    Diesel       Manual  Fourth & Above   12.8 kmpl
# ..                ...       ...          ...             ...         ...
# 70              73000    Petrol    Automatic           First    8.5 kmpl
# 71              55729    Diesel       Manual           First   15.1 kmpl
# 72              45178    Petrol    Automatic           First  16.95 kmpl
# 73              56066    Diesel       Manual           First  19.64 kmpl
# 74              37300    Petrol    Automatic          Second   16.5 kmpl
# 75              56000    Diesel    Automatic          Second  18.53 kmpl
# 76             111111    Diesel       Manual           First   17.8 kmpl
# 77             230000    Petrol       Manual           Third   12.4 kmpl
# 78             104000    Diesel       Manual           First   12.8 kmpl
# 79              87591    Petrol       Manual           First    0.0 kmpl
# 80              95100    Diesel       Manual           First   22.9 kmpl
# 81              70000    Petrol       Manual           First  17.57 kmpl
# 82              54944    Petrol       Manual           First   18.0 kmpl
# 83              70337    Diesel       Manual           First   20.0 kmpl
# 84              99638    Diesel       Manual           First   23.2 kmpl
# 85              52000    Petrol       Manual           First   17.8 kmpl
# 86              75000    Diesel    Automatic          Second  16.73 kmpl
# 87              95980    Petrol       Manual           First  20.36 kmpl
# 88              16000    Petrol       Manual           First   18.9 kmpl
# 89              73745    Petrol       Manual           First   17.0 kmpl
# 90              18949    Petrol       Manual           First   17.8 kmpl
# 91             107000    Diesel       Manual           First   13.0 kmpl
# 92              48367    Diesel    Automatic           First  17.68 kmpl
# 93              57000    Diesel       Manual           First   22.7 kmpl
# 94              58000    Diesel       Manual           First   15.1 kmpl
# 95              30000    Diesel       Manual           First   25.8 kmpl
# 96              34212    Diesel       Manual           First  22.07 kmpl
# 97              70002    Diesel       Manual           First   16.2 kmpl
# 98              62000    Petrol       Manual           First   18.9 kmpl
# 99              62001    Petrol       Manual           First  15.26 kmpl
#
#      Engine       Power  Seats  Price
# 0    998 CC   58.16 bhp    5.0   1.75
# 1   1582 CC   126.2 bhp    5.0  12.50
# 2   1199 CC    88.7 bhp    5.0   4.50
# 3   1248 CC   88.76 bhp    7.0   6.00
# 4   1968 CC   140.8 bhp    5.0  17.74
# 5    814 CC    55.2 bhp    5.0   2.35
# 6   1461 CC    63.1 bhp    5.0   3.50
# 7   2755 CC   171.5 bhp    8.0  17.50
# 8   1598 CC   103.6 bhp    5.0   5.20
# 9   1248 CC      74 bhp    5.0   1.95
# 10  1462 CC  103.25 bhp    5.0   9.95
# 11  1497 CC   116.3 bhp    5.0   4.49
# 12  1248 CC      74 bhp    5.0   5.60
# 13  2179 CC   187.7 bhp    5.0  27.00
# 14  2179 CC     115 bhp    5.0  17.50
# 15  2477 CC  175.56 bhp    7.0  15.00
# 16  1498 CC    98.6 bhp    5.0   5.40
# 17  1248 CC      74 bhp    5.0   5.99
# 18  1461 CC    83.8 bhp    5.0   6.34
# 19  2143 CC  167.62 bhp    5.0  28.00
# 20  1995 CC     190 bhp    5.0  18.55
# 21  1248 CC    88.5 bhp    5.0   8.25
# 22  1984 CC  177.01 bhp    5.0  23.50
# 23  1197 CC      80 bhp    5.0   1.87
# 24  1598 CC   103.6 bhp    5.0   2.85
# 25  1497 CC   116.3 bhp    5.0   4.25
# 26  1461 CC    63.1 bhp    5.0   4.25
# 27   998 CC    67.1 bhp    5.0   2.75
# 28  1199 CC    88.7 bhp    5.0   9.90
# 29  2494 CC     102 bhp    7.0   4.00
# ..      ...         ...    ...    ...
# 70  4806 CC     500 bhp    5.0  14.50
# 71  2179 CC     140 bhp    7.0   9.65
# 72  1197 CC    78.9 bhp    5.0   3.48
# 73  1461 CC   108.5 bhp    5.0   6.92
# 74  1198 CC    86.8 bhp    5.0   6.46
# 75  1968 CC  187.74 bhp    5.0  29.50
# 76  1399 CC    null bhp    5.0   2.00
# 77  1998 CC     132 bhp    8.0   4.50
# 78  2494 CC     102 bhp    7.0  11.75
# 79  1086 CC    null bhp    5.0   1.30
# 80  1248 CC      74 bhp    5.0   3.75
# 81  1193 CC    88.7 bhp    5.0   4.50
# 82  1198 CC    86.7 bhp    5.0   4.82
# 83  1399 CC      68 bhp    5.0   2.80
# 84  1248 CC   73.94 bhp    5.0   3.11
# 85  1497 CC   117.3 bhp    5.0   3.25
# 86  1995 CC     218 bhp    5.0  13.90
# 87  1197 CC    78.9 bhp    5.0   2.25
# 88  1197 CC      82 bhp    5.0   5.75
# 89  1086 CC    null bhp    5.0   2.10
# 90  1198 CC    86.7 bhp    5.0   5.00
# 91  2982 CC   168.5 bhp    7.0  16.50
# 92  1968 CC  174.33 bhp    5.0  39.58
# 93  1498 CC   89.84 bhp    5.0   5.50
# 94  2179 CC     140 bhp    7.0   8.10
# 95  1498 CC    98.6 bhp    5.0   3.50
# 96  1199 CC    73.9 bhp    5.0   2.79
# 97  1493 CC     110 bhp    5.0   3.45
# 98   998 CC    67.1 bhp    5.0   4.45
# 99  1598 CC   103.5 bhp    5.0   2.65
#
# [100 rows x 12 columns]

# %%
data_test.head()
# Out:
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                       Toyota Etios Liva GD   Hyderabad  2012
# 4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
#
#        Power  Seats
# 0   58.2 bhp    4.0
# 1   47.3 bhp    5.0
# 2  147.8 bhp    7.0
# 3   null bhp    5.0
# 4  82.85 bhp    5.0

# %%
data_train.shape
# Out:
# (6019, 12)

# %%
data_train.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
# Name                 6019 non-null object
# Location             6019 non-null object
# Year                 6019 non-null int64
# Kilometers_Driven    6019 non-null int64
# Fuel_Type            6019 non-null object
# Transmission         6019 non-null object
# Owner_Type           6019 non-null object
# Mileage              6017 non-null object
# Engine               5983 non-null object
# Power                5983 non-null object
# Seats                5977 non-null float64
# Price                6019 non-null float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 564.4+ KB

# %% [markdown]
# # Preparing Data for model

# %%
# Get names of columns with missing values
cols_with_missing = [col for col in data_train.columns
                     if data_train[col].isnull().any()]
print("Columns with missing values:")
print(cols_with_missing)
# Out:
# Columns with missing values:
# ['Mileage', 'Engine', 'Power', 'Seats']

# %%
#we are going to enter the mean values in respective null columns
data_train['Seats'].fillna(data_train['Seats'].mean(),inplace=True)
data_test['Seats'].fillna(data_test['Seats'].mean(),inplace=True)

# %% [markdown]
# To achieve more accurate results we need more data to work with.
# Therefore we are going to merge the two sets of data given to us

# %%
data = pd.concat([data_train,data_test], sort=False)

# %%
plt.figure(figsize=(20,5))
data_train['Mileage'].value_counts().head(100).plot.bar()
plt.show()

# %% [markdown]
# NOTE: In case of mileage we are going to fill NaN values with mode i.e 17 kmpl
# Also I observed that some of the cars have 0.0kmpl mileage which is not practical therefore I am changing 0.0 kmpl to 17 kmpl

# %%
data_train['Mileage'] = data_train['Mileage'].fillna('17.0 kmpl')
data_test['Mileage'] = data_test['Mileage'].fillna('17.0 kmpl')


data_train['Mileage'] = data_train['Mileage'].replace("0.0 kmpl", "17.0 kmpl")
data_test['Mileage'] = data_test['Mileage'].replace("0.0 kmpl", "17.0 kmpl")

# %%
plt.figure(figsize=(20,5))
data['Engine'].value_counts().head(100).plot.bar()
plt.show()

# %% [markdown]
# It is clear that for engines mode value is 1197cc. Therefore we are going to fill 1197cc for NaN values in Engine column

# %%
data_train['Engine'] = data_train['Engine'].fillna('1197 CC')
data_test['Engine'] = data_test['Engine'].fillna('1197 CC')

# %%
plt.figure(figsize=(20,5))
data['Power'].value_counts().head(100).plot.bar()
plt.show()

# %% [markdown]
# we can see that mode for Power column is 74bhp.
# Therefore we can fill 74 bhp in place for Nan value
#
# Also I observed that some of the entries in power column contains "null bhp" as entries
# Therfore we need to replace that as well with 74 bhp

# %%
data_train['Power'] = data_train['Power'].fillna('74 bhp')
data_test['Power'] = data_test['Power'].fillna('74 bhp')


data_train['Power'] = data_train['Power'].replace("null bhp", "74 bhp")
data_test['Power'] = data_test['Power'].replace("null bhp", "74 bhp")

# %%
data_train.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7253 entries, 0 to 1233
# Data columns (total 12 columns):
# Name                 7253 non-null object
# Location             7253 non-null object
# Year                 7253 non-null int64
# Kilometers_Driven    7253 non-null int64
# Fuel_Type            7253 non-null object
# Transmission         7253 non-null object
# Owner_Type           7253 non-null object
# Mileage              7251 non-null object
# Engine               7207 non-null object
# Power                7207 non-null object
# Seats                7253 non-null float64
# Price                6019 non-null float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 736.6+ KB

# %% [markdown]
# To be able to utilise this data we need to convert power, engine , mileage to float ,float ,float respectively

# %%
data_train['Mileage'] = data_train['Mileage'].apply(lambda x : str(x).split(' ')[0]).astype(float)
data_test['Mileage'] = data_test['Mileage'].apply(lambda x : str(x).split(' ')[0]).astype(float)

# %%
data_train['Engine'] = data_train['Engine'].apply(lambda x : str(x).split(" ")[0]).astype(float)
data_test['Engine'] = data_test['Engine'].apply(lambda x : str(x).split(" ")[0]).astype(float)

# %%
data_train['Power'] = data_train['Power'].apply(lambda x : str(x).split(' ')[0]).astype(float)
data_test['Power'] = data_test['Power'].apply(lambda x : str(x).split(' ')[0]).astype(float)

# %%
data_train['Year'] = data_train['Year'].astype(int)
data_train['Location'] = data_train['Location'].astype('category')
data_train['Fuel_Type'] = data_train['Fuel_Type'].astype('category')
data_train['Transmission'] = data_train['Transmission'].astype('category')
data_train['Owner_Type'] = data_train['Owner_Type'].astype('category')

data_test['Year'] = data_test['Year'].astype(int)
data_test['Location'] = data_test['Location'].astype('category')
data_test['Fuel_Type'] = data_test['Fuel_Type'].astype('category')
data_test['Transmission'] = data_test['Transmission'].astype('category')
data_test['Owner_Type'] = data_test['Owner_Type'].astype('category')

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
# Name                 6019 non-null object
# Location             6019 non-null category
# Year                 6019 non-null int32
# Kilometers_Driven    6019 non-null int64
# Fuel_Type            6019 non-null category
# Transmission         6019 non-null category
# Owner_Type           6019 non-null category
# Mileage              6019 non-null float64
# Engine               6019 non-null float64
# Power                6019 non-null float64
# Seats                6019 non-null float64
# Price                6019 non-null float64
# dtypes: category(4), float64(5), int32(1), int64(1), object(1)
# memory usage: 377.1+ KB

# %%
from sklearn.model_selection import train_test_split

y = np.log1p(data_train.Price)  
X = data_train.drop(['Price'],axis=1)


X_train, X_valid, y_train, y_valid = train_test_split(X,y,train_size=0.82,test_size=0.18,random_state=0)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()


X_train['Name'] = label_encoder.fit_transform(X_train['Name'])
X_valid['Name'] = label_encoder.fit_transform(X_valid['Name'])
data_test['Name'] = label_encoder.fit_transform(data_test['Name'])

X_train['Location'] = label_encoder.fit_transform(X_train['Location'])
X_valid['Location'] = label_encoder.fit_transform(X_valid['Location'])
data_test['Location'] = label_encoder.fit_transform(data_test['Location'])

X_train['Fuel_Type'] = label_encoder.fit_transform(X_train['Fuel_Type'])
X_valid['Fuel_Type'] = label_encoder.fit_transform(X_valid['Fuel_Type'])
data_test['Fuel_Type'] = label_encoder.fit_transform(data_test['Fuel_Type'])

X_train['Transmission'] = label_encoder.fit_transform(X_train['Transmission'])
X_valid['Transmission'] = label_encoder.fit_transform(X_valid['Transmission'])
data_test['Transmission'] = label_encoder.fit_transform(data_test['Transmission'])

X_train['Owner_Type'] = label_encoder.fit_transform(X_train['Owner_Type'])
X_valid['Owner_Type'] = label_encoder.fit_transform(X_valid['Owner_Type'])
data_test['Owner_Type'] = label_encoder.fit_transform(data_test['Owner_Type'])
# Out:
# C:\Users\anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_train.head()
# Out:
#       Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 2058  1320         7  2015              75863          1             1
# 898    384         4  2010              43000          4             1
# 2624   517         7  2015              66337          1             1
# 794    693         9  2018              19500          4             1
# 2141  1448         2  2016              78000          1             1
#
#       Owner_Type  Mileage  Engine   Power  Seats
# 2058           0    19.01  1461.0  108.45    5.0
# 898            2    16.80  1497.0  116.30    5.0
# 2624           0    24.00  1120.0   70.00    5.0
# 794            0    18.60  1197.0   81.83    5.0
# 2141           2    25.00  1396.0   69.01    5.0

# %% [markdown]
# # MODEL

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_squared_log_error

my_model = XGBRegressor(n_estimators=1000, learning_rate=0.05)
my_model.fit(X_train, y_train, 
             early_stopping_rounds=5, 
             eval_set=[(X_valid, y_valid)], 
             verbose=False)

predictions = my_model.predict(X_valid)
print("MAE: " + str(mean_absolute_error(predictions, y_valid)))
print("MSE: " + str(mean_squared_error(predictions, y_valid)))
print("MSLE: " + str(mean_squared_log_error(predictions, y_valid)))
# Out:
# MAE: 0.1530026872218476
# MSE: 0.04943186861580783
# MSLE: 0.005273767548709688

# %% [markdown]
# # PREDICTION

# %%
preds_test = my_model.predict(data_test)
preds_test = np.exp(preds_test)-1 #converting target to original state
print(preds_test)

preds_test = preds_test.round(2)
print(preds_test)
# Out:
# [ 3.2883463  2.819519  15.942518  ...  2.780071   5.6517634 16.553848 ]
# [ 3.29  2.82 15.94 ...  2.78  5.65 16.55]

# %%
output = pd.DataFrame({'Price': preds_test})
output.to_excel('submission.xlsx', index=False)
